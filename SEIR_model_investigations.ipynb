# %%
import numpy as np
import pandas as pd

from SEIR_model import compute_SEIR_model

# %%
compute_SEIR_model(N=67e06,R0=4.0, ndays=180, interventions=False)
# Out:
# [INFO] R0:: 4.0
# [INFO] Alpha1:: 2.835820895522388e-09
# [INFO] Alpha2:: 1.4925373134328362e-10
# [INFO] Beta:: 0.1
# [INFO] Gamma:: 0.06785714285714285
# [INFO] Psi:: 0.005
# ************************************************
# ***          SEIR MODEL RUN RESULTS          ***
# ************************************************
#
# Total number of fatalities::  4565914
# Total number of confirmed cases:: 66983658
#
# Finished.

# %%
interventions = {'social_distancing':{'day':100, 'reproduction_rate':2},
                 'lockdown':{'day':110, 'reproduction_rate':.5}}

compute_SEIR_model(N=67e06,R0=4.0, ndays=180,interventions=interventions)
# Out:
# [INFO] R0:: 4.0
# [INFO] Alpha1:: 2.835820895522388e-09
# [INFO] Alpha2:: 1.4925373134328362e-10
# [INFO] Beta:: 0.1
# [INFO] Gamma:: 0.06785714285714285
# [INFO] Psi:: 0.005
# ************************************************
# ***          SEIR MODEL RUN RESULTS          ***
# ************************************************
#
# Total number of fatalities::  4503182
# Total number of confirmed cases:: 66116933
#
# Finished.
